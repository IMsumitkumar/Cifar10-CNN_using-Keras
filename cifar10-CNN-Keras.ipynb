# %%
import keras
from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %%
# rescale [0,255] -------> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

print('x_train shape:', x_train.shape)

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 21s - loss: 1.5818 - acc: 0.4235 - val_loss: 1.3008 - val_acc: 0.5246
#
# Epoch 00001: val_loss improved from inf to 1.30083, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 7s - loss: 1.2403 - acc: 0.5569 - val_loss: 1.1398 - val_acc: 0.5840
#
# Epoch 00002: val_loss improved from 1.30083 to 1.13977, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 7s - loss: 1.1243 - acc: 0.6038 - val_loss: 1.0365 - val_acc: 0.6330
#
# Epoch 00003: val_loss improved from 1.13977 to 1.03648, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 7s - loss: 1.0555 - acc: 0.6285 - val_loss: 1.0222 - val_acc: 0.6424
#
# Epoch 00004: val_loss improved from 1.03648 to 1.02215, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 8s - loss: 1.0140 - acc: 0.6500 - val_loss: 0.9053 - val_acc: 0.6830
#
# Epoch 00005: val_loss improved from 1.02215 to 0.90531, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 8s - loss: 0.9921 - acc: 0.6536 - val_loss: 1.0305 - val_acc: 0.6350
#
# Epoch 00006: val_loss did not improve from 0.90531
# Epoch 7/100
#  - 8s - loss: 0.9724 - acc: 0.6636 - val_loss: 0.9103 - val_acc: 0.6918
#
# Epoch 00007: val_loss did not improve from 0.90531
# Epoch 8/100
#  - 8s - loss: 0.9710 - acc: 0.6674 - val_loss: 0.9992 - val_acc: 0.6750
#
# Epoch 00008: val_loss did not improve from 0.90531
# Epoch 9/100
#  - 7s - loss: 0.9696 - acc: 0.6702 - val_loss: 0.9501 - val_acc: 0.6878
#
# Epoch 00009: val_loss did not improve from 0.90531
# Epoch 10/100
#  - 8s - loss: 0.9843 - acc: 0.6681 - val_loss: 1.0923 - val_acc: 0.6222
#
# Epoch 00010: val_loss did not improve from 0.90531
# Epoch 11/100
#  - 7s - loss: 0.9916 - acc: 0.6656 - val_loss: 1.1010 - val_acc: 0.6320
#
# Epoch 00011: val_loss did not improve from 0.90531
# Epoch 12/100
#  - 7s - loss: 0.9986 - acc: 0.6661 - val_loss: 0.8990 - val_acc: 0.6994
#
# Epoch 00012: val_loss improved from 0.90531 to 0.89899, saving model to model.weights.best.hdf5
# Epoch 13/100
#  - 7s - loss: 1.0088 - acc: 0.6643 - val_loss: 1.0186 - val_acc: 0.6744
#
# Epoch 00013: val_loss did not improve from 0.89899
# Epoch 14/100
#  - 7s - loss: 1.0317 - acc: 0.6583 - val_loss: 1.0360 - val_acc: 0.6764
#
# Epoch 00014: val_loss did not improve from 0.89899
# Epoch 15/100
#  - 7s - loss: 1.0299 - acc: 0.6581 - val_loss: 1.4265 - val_acc: 0.6394
#
# Epoch 00015: val_loss did not improve from 0.89899
# Epoch 16/100
#  - 7s - loss: 1.0519 - acc: 0.6493 - val_loss: 1.0043 - val_acc: 0.6642
#
# Epoch 00016: val_loss did not improve from 0.89899
# Epoch 17/100
#  - 7s - loss: 1.0690 - acc: 0.6451 - val_loss: 1.0777 - val_acc: 0.6414
#
# Epoch 00017: val_loss did not improve from 0.89899
# Epoch 18/100
#  - 7s - loss: 1.0818 - acc: 0.6403 - val_loss: 0.9644 - val_acc: 0.6760
#
# Epoch 00018: val_loss did not improve from 0.89899
# Epoch 19/100
#  - 7s - loss: 1.1023 - acc: 0.6374 - val_loss: 1.7990 - val_acc: 0.5470
#
# Epoch 00019: val_loss did not improve from 0.89899
# Epoch 20/100
#  - 8s - loss: 1.1239 - acc: 0.6293 - val_loss: 1.1113 - val_acc: 0.6332
#
# Epoch 00020: val_loss did not improve from 0.89899
# Epoch 21/100
#  - 7s - loss: 1.1406 - acc: 0.6244 - val_loss: 1.2846 - val_acc: 0.5990
#
# Epoch 00021: val_loss did not improve from 0.89899
# Epoch 22/100
#  - 8s - loss: 1.1529 - acc: 0.6233 - val_loss: 1.5263 - val_acc: 0.5878
#
# Epoch 00022: val_loss did not improve from 0.89899
# Epoch 23/100
#  - 7s - loss: 1.1815 - acc: 0.6123 - val_loss: 1.3100 - val_acc: 0.5772
#
# Epoch 00023: val_loss did not improve from 0.89899
# Epoch 24/100
#  - 7s - loss: 1.1959 - acc: 0.6064 - val_loss: 1.0621 - val_acc: 0.6686
#
# Epoch 00024: val_loss did not improve from 0.89899
# Epoch 25/100
#  - 7s - loss: 1.2212 - acc: 0.6008 - val_loss: 1.2873 - val_acc: 0.5462
#
# Epoch 00025: val_loss did not improve from 0.89899
# Epoch 26/100
#  - 7s - loss: 1.2332 - acc: 0.5967 - val_loss: 1.0817 - val_acc: 0.6272
#
# Epoch 00026: val_loss did not improve from 0.89899
# Epoch 27/100
#  - 7s - loss: 1.2404 - acc: 0.5914 - val_loss: 1.1023 - val_acc: 0.6416
#
# Epoch 00027: val_loss did not improve from 0.89899
# Epoch 28/100
#  - 8s - loss: 1.2586 - acc: 0.5826 - val_loss: 1.7337 - val_acc: 0.5750
#
# Epoch 00028: val_loss did not improve from 0.89899
# Epoch 29/100
#  - 7s - loss: 1.2841 - acc: 0.5780 - val_loss: 1.2824 - val_acc: 0.5638
#
# Epoch 00029: val_loss did not improve from 0.89899
# Epoch 30/100
#  - 7s - loss: 1.2841 - acc: 0.5785 - val_loss: 1.0495 - val_acc: 0.6466
#
# Epoch 00030: val_loss did not improve from 0.89899
# Epoch 31/100
#  - 7s - loss: 1.3104 - acc: 0.5684 - val_loss: 1.1946 - val_acc: 0.6022
#
# Epoch 00031: val_loss did not improve from 0.89899
# Epoch 32/100
#  - 8s - loss: 1.3232 - acc: 0.5644 - val_loss: 1.3339 - val_acc: 0.5358
#
# Epoch 00032: val_loss did not improve from 0.89899
# Epoch 33/100
#  - 8s - loss: 1.3342 - acc: 0.5635 - val_loss: 1.2573 - val_acc: 0.6118
#
# Epoch 00033: val_loss did not improve from 0.89899
# Epoch 34/100
#  - 8s - loss: 1.3492 - acc: 0.5548 - val_loss: 1.2714 - val_acc: 0.6154
#
# Epoch 00034: val_loss did not improve from 0.89899
# Epoch 35/100
#  - 7s - loss: 1.3628 - acc: 0.5528 - val_loss: 1.0224 - val_acc: 0.6554
#
# Epoch 00035: val_loss did not improve from 0.89899
# Epoch 36/100
#  - 8s - loss: 1.3827 - acc: 0.5403 - val_loss: 1.2068 - val_acc: 0.6120
#
# Epoch 00036: val_loss did not improve from 0.89899
# Epoch 37/100
#  - 7s - loss: 1.4090 - acc: 0.5363 - val_loss: 1.1634 - val_acc: 0.6010
#
# Epoch 00037: val_loss did not improve from 0.89899
# Epoch 38/100
#  - 8s - loss: 1.4214 - acc: 0.5338 - val_loss: 1.6486 - val_acc: 0.4732
#
# Epoch 00038: val_loss did not improve from 0.89899
# Epoch 39/100
#  - 7s - loss: 1.4283 - acc: 0.5269 - val_loss: 1.2933 - val_acc: 0.5972
#
# Epoch 00039: val_loss did not improve from 0.89899
# Epoch 40/100
#  - 7s - loss: 1.4401 - acc: 0.5229 - val_loss: 1.2622 - val_acc: 0.5698
#
# Epoch 00040: val_loss did not improve from 0.89899
# Epoch 41/100
#  - 8s - loss: 1.4361 - acc: 0.5203 - val_loss: 1.3174 - val_acc: 0.5354
#
# Epoch 00041: val_loss did not improve from 0.89899
# Epoch 42/100
#  - 7s - loss: 1.4529 - acc: 0.5192 - val_loss: 1.2576 - val_acc: 0.5814
#
# Epoch 00042: val_loss did not improve from 0.89899
# Epoch 43/100
#  - 7s - loss: 1.4482 - acc: 0.5157 - val_loss: 1.2934 - val_acc: 0.5454
#
# Epoch 00043: val_loss did not improve from 0.89899
# Epoch 44/100
#  - 7s - loss: 1.4658 - acc: 0.5138 - val_loss: 1.6081 - val_acc: 0.4702
#
# Epoch 00044: val_loss did not improve from 0.89899
# Epoch 45/100
#  - 8s - loss: 1.4697 - acc: 0.5125 - val_loss: 1.1812 - val_acc: 0.5800
#
# Epoch 00045: val_loss did not improve from 0.89899
# Epoch 46/100
#  - 8s - loss: 1.4909 - acc: 0.5093 - val_loss: 4.1270 - val_acc: 0.3306
#
# Epoch 00046: val_loss did not improve from 0.89899
# Epoch 47/100
#  - 8s - loss: 1.4895 - acc: 0.5044 - val_loss: 1.6664 - val_acc: 0.5108
#
# Epoch 00047: val_loss did not improve from 0.89899
# Epoch 48/100
#  - 8s - loss: 1.4893 - acc: 0.5027 - val_loss: 1.6431 - val_acc: 0.3838
#
# Epoch 00048: val_loss did not improve from 0.89899
# Epoch 49/100
#  - 7s - loss: 1.5039 - acc: 0.5002 - val_loss: 3.5915 - val_acc: 0.4442
#
# Epoch 00049: val_loss did not improve from 0.89899
# Epoch 50/100
#  - 8s - loss: 1.5082 - acc: 0.4977 - val_loss: 1.3895 - val_acc: 0.5140
#
# Epoch 00050: val_loss did not improve from 0.89899
# Epoch 51/100
#  - 8s - loss: 1.5017 - acc: 0.4996 - val_loss: 1.3036 - val_acc: 0.5532
#
# Epoch 00051: val_loss did not improve from 0.89899
# Epoch 52/100
#  - 7s - loss: 1.5098 - acc: 0.4961 - val_loss: 1.5806 - val_acc: 0.4914
#
# Epoch 00052: val_loss did not improve from 0.89899
# Epoch 53/100
#  - 8s - loss: 1.5112 - acc: 0.4912 - val_loss: 2.1541 - val_acc: 0.4236
#
# Epoch 00053: val_loss did not improve from 0.89899
# Epoch 54/100
#  - 7s - loss: 1.5216 - acc: 0.4916 - val_loss: 1.7739 - val_acc: 0.3682
#
# Epoch 00054: val_loss did not improve from 0.89899
# Epoch 55/100
#  - 8s - loss: 1.5232 - acc: 0.4856 - val_loss: 3.7153 - val_acc: 0.3268
#
# Epoch 00055: val_loss did not improve from 0.89899
# Epoch 56/100
#  - 7s - loss: 1.5216 - acc: 0.4908 - val_loss: 1.2352 - val_acc: 0.5832
#
# Epoch 00056: val_loss did not improve from 0.89899
# Epoch 57/100
#  - 7s - loss: 1.5389 - acc: 0.4844 - val_loss: 1.4022 - val_acc: 0.5202
#
# Epoch 00057: val_loss did not improve from 0.89899
# Epoch 58/100
#  - 8s - loss: 1.5356 - acc: 0.4823 - val_loss: 1.3640 - val_acc: 0.5626
#
# Epoch 00058: val_loss did not improve from 0.89899
# Epoch 59/100
#  - 7s - loss: 1.5489 - acc: 0.4811 - val_loss: 1.5261 - val_acc: 0.4376
#
# Epoch 00059: val_loss did not improve from 0.89899
# Epoch 60/100
#  - 8s - loss: 1.5539 - acc: 0.4774 - val_loss: 1.2874 - val_acc: 0.5384
#
# Epoch 00060: val_loss did not improve from 0.89899
# Epoch 61/100
#  - 7s - loss: 1.5607 - acc: 0.4739 - val_loss: 1.3783 - val_acc: 0.5486
#
# Epoch 00061: val_loss did not improve from 0.89899
# Epoch 62/100
#  - 7s - loss: 1.5610 - acc: 0.4758 - val_loss: 1.2795 - val_acc: 0.5576
#
# Epoch 00062: val_loss did not improve from 0.89899
# Epoch 63/100
#  - 8s - loss: 1.5662 - acc: 0.4749 - val_loss: 1.3876 - val_acc: 0.5000
#
# Epoch 00063: val_loss did not improve from 0.89899
# Epoch 64/100
#  - 8s - loss: 1.5789 - acc: 0.4704 - val_loss: 1.4910 - val_acc: 0.5046
#
# Epoch 00064: val_loss did not improve from 0.89899
# Epoch 65/100
#  - 7s - loss: 1.5609 - acc: 0.4730 - val_loss: 1.2540 - val_acc: 0.5580
#
# Epoch 00065: val_loss did not improve from 0.89899
# Epoch 66/100
#  - 7s - loss: 1.5651 - acc: 0.4734 - val_loss: 1.4017 - val_acc: 0.5254
#
# Epoch 00066: val_loss did not improve from 0.89899
# Epoch 67/100
#  - 7s - loss: 1.5871 - acc: 0.4609 - val_loss: 1.5461 - val_acc: 0.5008
#
# Epoch 00067: val_loss did not improve from 0.89899
# Epoch 68/100
#  - 8s - loss: 1.5701 - acc: 0.4653 - val_loss: 1.5826 - val_acc: 0.5192
#
# Epoch 00068: val_loss did not improve from 0.89899
# Epoch 69/100
#  - 7s - loss: 1.5811 - acc: 0.4638 - val_loss: 2.7206 - val_acc: 0.3872
#
# Epoch 00069: val_loss did not improve from 0.89899
# Epoch 70/100
#  - 7s - loss: 1.5782 - acc: 0.4666 - val_loss: 1.2890 - val_acc: 0.5716
#
# Epoch 00070: val_loss did not improve from 0.89899
# Epoch 71/100
#  - 7s - loss: 1.5904 - acc: 0.4586 - val_loss: 1.3624 - val_acc: 0.5678
#
# Epoch 00071: val_loss did not improve from 0.89899
# Epoch 72/100
#  - 7s - loss: 1.5943 - acc: 0.4579 - val_loss: 1.3512 - val_acc: 0.5352
#
# Epoch 00072: val_loss did not improve from 0.89899
# Epoch 73/100
#  - 8s - loss: 1.5919 - acc: 0.4577 - val_loss: 1.2742 - val_acc: 0.5682
#
# Epoch 00073: val_loss did not improve from 0.89899
# Epoch 74/100
#  - 7s - loss: 1.5843 - acc: 0.4607 - val_loss: 1.3461 - val_acc: 0.5144
#
# Epoch 00074: val_loss did not improve from 0.89899
# Epoch 75/100
#  - 7s - loss: 1.6046 - acc: 0.4541 - val_loss: 1.4594 - val_acc: 0.4828
#
# Epoch 00075: val_loss did not improve from 0.89899
# Epoch 76/100
#  - 7s - loss: 1.6083 - acc: 0.4500 - val_loss: 1.3572 - val_acc: 0.5066
#
# Epoch 00076: val_loss did not improve from 0.89899
# Epoch 77/100
#  - 7s - loss: 1.5959 - acc: 0.4531 - val_loss: 1.3303 - val_acc: 0.5280
#
# Epoch 00077: val_loss did not improve from 0.89899
# Epoch 78/100
#  - 8s - loss: 1.6220 - acc: 0.4489 - val_loss: 1.5287 - val_acc: 0.4974
#
# Epoch 00078: val_loss did not improve from 0.89899
# Epoch 79/100
#  - 7s - loss: 1.6047 - acc: 0.4550 - val_loss: 1.2914 - val_acc: 0.5312
#
# Epoch 00079: val_loss did not improve from 0.89899
# Epoch 80/100
#  - 7s - loss: 1.6152 - acc: 0.4491 - val_loss: 1.4070 - val_acc: 0.4728
#
# Epoch 00080: val_loss did not improve from 0.89899
# Epoch 81/100
#  - 7s - loss: 1.6175 - acc: 0.4475 - val_loss: 1.7297 - val_acc: 0.4208
#
# Epoch 00081: val_loss did not improve from 0.89899
# Epoch 82/100
#  - 7s - loss: 1.6284 - acc: 0.4423 - val_loss: 1.5045 - val_acc: 0.4738
#
# Epoch 00082: val_loss did not improve from 0.89899
# Epoch 83/100
#  - 7s - loss: 1.6338 - acc: 0.4399 - val_loss: 1.5095 - val_acc: 0.5162
#
# Epoch 00083: val_loss did not improve from 0.89899
# Epoch 84/100
#  - 7s - loss: 1.6235 - acc: 0.4470 - val_loss: 1.6286 - val_acc: 0.4002
#
# Epoch 00084: val_loss did not improve from 0.89899
# Epoch 85/100
#  - 7s - loss: 1.6318 - acc: 0.4389 - val_loss: 1.3062 - val_acc: 0.5254
#
# Epoch 00085: val_loss did not improve from 0.89899
# Epoch 86/100
#  - 7s - loss: 1.6354 - acc: 0.4387 - val_loss: 1.6100 - val_acc: 0.4350
#
# Epoch 00086: val_loss did not improve from 0.89899
# Epoch 87/100
#  - 7s - loss: 1.6332 - acc: 0.4397 - val_loss: 1.7644 - val_acc: 0.4364
#
# Epoch 00087: val_loss did not improve from 0.89899
# Epoch 88/100
#  - 7s - loss: 1.6402 - acc: 0.4368 - val_loss: 1.4048 - val_acc: 0.5098
#
# Epoch 00088: val_loss did not improve from 0.89899
# Epoch 89/100
#  - 7s - loss: 1.6436 - acc: 0.4361 - val_loss: 1.4188 - val_acc: 0.5188
#
# Epoch 00089: val_loss did not improve from 0.89899
# Epoch 90/100
#  - 7s - loss: 1.6452 - acc: 0.4344 - val_loss: 1.6427 - val_acc: 0.3812
#
# Epoch 00090: val_loss did not improve from 0.89899
# Epoch 91/100
#  - 7s - loss: 1.6538 - acc: 0.4351 - val_loss: 1.9051 - val_acc: 0.5054
#
# Epoch 00091: val_loss did not improve from 0.89899
# Epoch 92/100
#  - 7s - loss: 1.6598 - acc: 0.4319 - val_loss: 1.8652 - val_acc: 0.3848
#
# Epoch 00092: val_loss did not improve from 0.89899
# Epoch 93/100
#  - 7s - loss: 1.6796 - acc: 0.4290 - val_loss: 1.4473 - val_acc: 0.4688
#
# Epoch 00093: val_loss did not improve from 0.89899
# Epoch 94/100
#  - 7s - loss: 1.6736 - acc: 0.4263 - val_loss: 1.6769 - val_acc: 0.3646
#
# Epoch 00094: val_loss did not improve from 0.89899
# Epoch 95/100
#  - 7s - loss: 1.6792 - acc: 0.4245 - val_loss: 1.6080 - val_acc: 0.4650
#
# Epoch 00095: val_loss did not improve from 0.89899
# Epoch 96/100
#  - 7s - loss: 1.6722 - acc: 0.4262 - val_loss: 1.4394 - val_acc: 0.4908
#
# Epoch 00096: val_loss did not improve from 0.89899
# Epoch 97/100
#  - 7s - loss: 1.6926 - acc: 0.4168 - val_loss: 1.3711 - val_acc: 0.5126
#
# Epoch 00097: val_loss did not improve from 0.89899
# Epoch 98/100
#  - 7s - loss: 1.7016 - acc: 0.4166 - val_loss: 1.4714 - val_acc: 0.4882
#
# Epoch 00098: val_loss did not improve from 0.89899
# Epoch 99/100
#  - 8s - loss: 1.6866 - acc: 0.4153 - val_loss: 1.5851 - val_acc: 0.4420
#
# Epoch 00099: val_loss did not improve from 0.89899
# Epoch 100/100
#  - 7s - loss: 1.7002 - acc: 0.4114 - val_loss: 1.3341 - val_acc: 0.5222
#
# Epoch 00100: val_loss did not improve from 0.89899

# %%
# load the weights 
model.load_weights('model.weights.best.hdf5')

# %%
# evaluate  test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6931

# %%
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
